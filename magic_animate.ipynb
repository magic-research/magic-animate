# %% [markdown]
# <a href="https://colab.research.google.com/github/catyung/magic-animate/blob/main/magic_animate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MagicAnimate: Temporally Consistent Human Image Animation using Diffusion Model
#
# Github :
# https://github.com/magic-research/magic-animate
#
# Paper :
# https://arxiv.org/abs/2311.16498
#
# Project :
# https://showlab.github.io/magicanimate/
#
# If there is any problem on the colab code, please contact me at : cat@super-cat.tech

# %% [markdown]
# # Install
# The following demo needs to use A100 GPU, high ram and please make sure your disk is having 100+GBs for models

# %%
# !git clone https://github.com/magic-research/magic-animate
# Out:
# Cloning into 'magic-animate'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 124 (delta 37), reused 22 (delta 22), pack-reused 73
# Receiving objects: 100% (124/124), 24.87 MiB | 4.83 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
# !pip install -r /content/magic-animate/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 18.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 23.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.8/201.8 kB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 75.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 kB 35.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 54.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Downloading checkpoints & relocate the models
#
# Here is the expected folder structure :
# ```
# magic-animate
# |----pretrained_models
#   |----MagicAnimate
#     |----appearance_encoder
#       |----diffusion_pytorch_model.safetensors
#       |----config.json
#     |----densepose_controlnet
#       |----diffusion_pytorch_model.safetensors
#       |----config.json
#     |----temporal_attention
#       |----temporal_attention.ckpt
#   |----sd-vae-ft-mse
#     |----...
#   |----stable-diffusion-v1-5
#     |----...
# |----...
# ```

# %%
# !git lfs clone https://huggingface.co/zcxu-eric/MagicAnimate
# Out:
# WARNING: 'git lfs clone' is deprecated and will not be updated
#           with new flags from 'git clone'
#
# 'git clone' has been updated in upstream Git to have comparable
# speeds to 'git lfs clone'.
# Cloning into 'MagicAnimate'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17 (delta 2), reused 0 (delta 0), pack-reused 4
# Unpacking objects: 100% (17/17), 2.84 KiB | 970.00 KiB/s, done.

# %%
# !git lfs clone https://huggingface.co/runwayml/stable-diffusion-v1-5
# Out:
# WARNING: 'git lfs clone' is deprecated and will not be updated
#           with new flags from 'git clone'
#
# 'git clone' has been updated in upstream Git to have comparable
# speeds to 'git lfs clone'.
# Cloning into 'stable-diffusion-v1-5'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 194 (delta 34), reused 7 (delta 7), pack-reused 142
# Receiving objects: 100% (194/194), 541.34 KiB | 828.00 KiB/s, done.
# Resolving deltas: 100% (61/61), done.

# %%
# !git lfs clone https://huggingface.co/stabilityai/sd-vae-ft-mse
# Out:
# WARNING: 'git lfs clone' is deprecated and will not be updated
#           with new flags from 'git clone'
#
# 'git clone' has been updated in upstream Git to have comparable
# speeds to 'git lfs clone'.
# Cloning into 'sd-vae-ft-mse'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 28 (delta 0), reused 0 (delta 0), pack-reused 25
# Unpacking objects: 100% (28/28), 6.72 KiB | 982.00 KiB/s, done.

# %%
# create new folder
# !mkdir /content/magic-animate/pretrained_models

# move the checkpoints to the folder
# !mv /content/MagicAnimate /content/magic-animate/pretrained_models/MagicAnimate
# !mv /content/stable-diffusion-v1-5 /content/magic-animate/pretrained_models/stable-diffusion-v1-5
# !mv /content/sd-vae-ft-mse /content/magic-animate/pretrained_models/sd-vae-ft-mse

# %% [markdown]
# # Init Gradio Demo App
# After running the following lines, you will get :
#
# **Running on public URL**

# %%
# %cd /content/magic-animate
# init gradio demo

# make sure use demo.queue().launch(share=True) in gradio_animate.py
# !python3 -m demo.gradio_animate
# Out:
# 2023-12-11 09:05:17.289804: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 09:05:17.289871: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 09:05:17.289921: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-11 09:05:18.493504: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
